# %%
import pandas as pd
df = pd.read_excel('Awesome Electronics.xlsx')
df
# Out:
#          Countries        Products  Quantity  Revenue per product  \
# 0          Nigeria  Type A Charger     292.0                    5
# 1            Ghana  Type A Charger     974.0                    5
# 2          Nigeria  Type A Charger    2518.0                    5
# 3            Kenya  Type A Charger    1006.0                    5
# 4            Kenya  Type A Charger     367.0                    5
# ...            ...             ...       ...                  ...
# 1345        Zambia     Pin Charger     663.0                    6
# 1346  South Africa     Pin Charger    2574.0                    6
# 1347  South Africa     Pin Charger    2438.0                    6
# 1348  South Africa     Pin Charger     914.0                    6
# 1349  South Africa     Pin Charger     914.0                    6
#
#       Cost per product Order Date
# 0                 2.00 2022-02-01
# 1                 2.00 2022-02-01
# 2                 2.00 2022-06-01
# ...

# %%
#To check the data types
df.dtypes
# Out:
# Countries                      object
# Products                       object
# Quantity                      float64
# Revenue per product             int64
# Cost per product              float64
# Order Date             datetime64[ns]
# dtype: object

# %%
#To check the top 5
df.head(5)
# Out:
#   Countries        Products  Quantity  Revenue per product  Cost per product  \
# 0   Nigeria  Type A Charger     292.0                    5               2.0
# 1     Ghana  Type A Charger     974.0                    5               2.0
# 2   Nigeria  Type A Charger    2518.0                    5               2.0
# 3     Kenya  Type A Charger    1006.0                    5               2.0
# 4     Kenya  Type A Charger     367.0                    5               2.0
#
#   Order Date
# 0 2022-02-01
# 1 2022-02-01
# 2 2022-06-01
# 3 2022-06-01
# 4 2022-07-01

# %%
#To check the least 5 or last 5
df.tail(5)
# Out:
#          Countries     Products  Quantity  Revenue per product  \
# 1345        Zambia  Pin Charger     663.0                    6
# 1346  South Africa  Pin Charger    2574.0                    6
# 1347  South Africa  Pin Charger    2438.0                    6
# 1348  South Africa  Pin Charger     914.0                    6
# 1349  South Africa  Pin Charger     914.0                    6
#
#       Cost per product Order Date
# 1345              2.75 2022-09-01
# 1346              2.75 2021-11-01
# 1347              2.75 2021-12-01
# 1348              2.75 2022-12-01
# 1349              2.75 2022-12-01

# %%
#To check the number of rows, columns and basic properties
#df.shape - this checks the number of rows and cdataframe_columns
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1350 entries, 0 to 1349
# Data columns (total 6 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Countries            1350 non-null   object
#  1   Products             1350 non-null   object
#  2   Quantity             1350 non-null   float64
#  3   Revenue per product  1350 non-null   int64
#  4   Cost per product     1350 non-null   float64
#  5   Order Date           1350 non-null   datetime64[ns]
# dtypes: datetime64[ns](1), float64(2), int64(1), object(2)
# memory usage: 63.4+ KB

# %%
#To read the details of each columns
#df.Countries
#df.Products
df[['Countries', 'Products']]
# Out:
#          Countries        Products
# 0          Nigeria  Type A Charger
# 1            Ghana  Type A Charger
# 2          Nigeria  Type A Charger
# 3            Kenya  Type A Charger
# 4            Kenya  Type A Charger
# ...            ...             ...
# 1345        Zambia     Pin Charger
# 1346  South Africa     Pin Charger
# 1347  South Africa     Pin Charger
# 1348  South Africa     Pin Charger
# 1349  South Africa     Pin Charger
#
# [1350 rows x 2 columns]

# %%
#To read the details of specific row
#df.iloc[2]
#df.iloc[0:3]
df.iloc[1:4]
# Out:
#   Countries        Products  Quantity  Revenue per product  Cost per product  \
# 1     Ghana  Type A Charger     974.0                    5               2.0
# 2   Nigeria  Type A Charger    2518.0                    5               2.0
# 3     Kenya  Type A Charger    1006.0                    5               2.0
#
#   Order Date
# 1 2022-02-01
# 2 2022-06-01
# 3 2022-06-01

# %%
#To read specific details of location
#df.iloc[1,0]
#df.iloc[1,3]
df.iloc[1,5]
# Out:
# Timestamp('2022-02-01 00:00:00')

# %%
#Basic Mathematics
df['Revenue'] = df['Quantity'] * df['Revenue per product']
df['Cost'] = df['Quantity'] * df['Cost per product']
df['Profit'] = df['Revenue'] - df['Cost']
df
# Out:
#          Countries        Products  Quantity  Revenue per product  \
# 0          Nigeria  Type A Charger     292.0                    5
# 1            Ghana  Type A Charger     974.0                    5
# 2          Nigeria  Type A Charger    2518.0                    5
# 3            Kenya  Type A Charger    1006.0                    5
# 4            Kenya  Type A Charger     367.0                    5
# ...            ...             ...       ...                  ...
# 1345        Zambia     Pin Charger     663.0                    6
# 1346  South Africa     Pin Charger    2574.0                    6
# 1347  South Africa     Pin Charger    2438.0                    6
# 1348  South Africa     Pin Charger     914.0                    6
# 1349  South Africa     Pin Charger     914.0                    6
#
#       Cost per product Order Date  Revenue     Cost   Profit
# 0                 2.00 2022-02-01   1460.0   584.00   876.00
# ...

# %%
#SORTING A TABLE 
#df.sort_values('Countries')
#df.sort_values('Countries', ascending = False)
df.sort_values(['Countries', 'Quantity'], ascending = [1,0])
# Out:
#      Countries        Products  Quantity  Revenue per product  \
# 118      Ghana  Type A Charger    2993.0                    5
# 767      Ghana  Type A Charger    2993.0                    5
# 577      Ghana    Mini Charger    2903.0                    3
# 1226     Ghana    Mini Charger    2903.0                    3
# 620      Ghana     Pin Charger    2861.0                    6
# ...        ...             ...       ...                  ...
# 285     Zambia  Type B Charger     293.0                    1
# 589     Zambia    Mini Charger     293.0                    3
# 849     Zambia  Type A Charger     293.0                    5
# 934     Zambia  Type B Charger     293.0                    1
# 1238    Zambia    Mini Charger     293.0                    3
#
#       Cost per product Order Date  Revenue     Cost   Profit
# 118               2.00 2022-09-01  14965.0  5986.00  8979.00
# 767               2.00 2022-09-01  14965.0  5986.00  8979.00
# ...

# %%
df["Month"] = df["Order Date"].apply(lambda x : x. strftime('%B'))
df["Year"] = df["Order Date"].apply(lambda x : x. strftime('%Y'))
df
# Out:
#          Countries        Products  Quantity  Revenue per product  \
# 0          Nigeria  Type A Charger     292.0                    5
# 1            Ghana  Type A Charger     974.0                    5
# 2          Nigeria  Type A Charger    2518.0                    5
# 3            Kenya  Type A Charger    1006.0                    5
# 4            Kenya  Type A Charger     367.0                    5
# ...            ...             ...       ...                  ...
# 1345        Zambia     Pin Charger     663.0                    6
# 1346  South Africa     Pin Charger    2574.0                    6
# 1347  South Africa     Pin Charger    2438.0                    6
# 1348  South Africa     Pin Charger     914.0                    6
# 1349  South Africa     Pin Charger     914.0                    6
#
#       Cost per product Order Date  Revenue     Cost   Profit      Month  Year
# 0                 2.00 2022-02-01   1460.0   584.00   876.00   February  2022
# ...

# %%
#To filter out specific info
df.loc[df['Countries'] == "Nigeria"]
# Out:
#      Countries        Products  Quantity  Revenue per product  \
# 0      Nigeria  Type A Charger     292.0                    5
# 2      Nigeria  Type A Charger    2518.0                    5
# 10     Nigeria  Type A Charger    1725.0                    5
# 12     Nigeria  Type A Charger    2152.0                    5
# 13     Nigeria  Type A Charger    1817.0                    5
# ...        ...             ...       ...                  ...
# 1319   Nigeria     Pin Charger    1916.0                    6
# 1321   Nigeria     Pin Charger     384.0                    6
# 1326   Nigeria     Pin Charger    1808.0                    6
# 1331   Nigeria     Pin Charger    2632.0                    6
# 1341   Nigeria     Pin Charger     269.0                    6
#
#       Cost per product Order Date  Revenue     Cost   Profit     Month  Year
# 0                 2.00 2022-02-01   1460.0   584.00   876.00  February  2022
# ...

# %%
#Filters by a single products
df.query("Products == 'Pin Charger'")
# Out:
#          Countries     Products  Quantity  Revenue per product  \
# 591          Ghana  Pin Charger    1493.0                    6
# 592         Zambia  Pin Charger    1804.0                    6
# 593          Kenya  Pin Charger    2161.0                    6
# 594          Kenya  Pin Charger    1006.0                    6
# 595          Kenya  Pin Charger    1545.0                    6
# ...            ...          ...       ...                  ...
# 1345        Zambia  Pin Charger     663.0                    6
# 1346  South Africa  Pin Charger    2574.0                    6
# 1347  South Africa  Pin Charger    2438.0                    6
# 1348  South Africa  Pin Charger     914.0                    6
# 1349  South Africa  Pin Charger     914.0                    6
#
#       Cost per product Order Date  Revenue     Cost   Profit      Month  Year
# 591               2.75 2022-01-01   8958.0  4105.75  4852.25    January  2022
# ...

# %%
#Filters other products except pin charger
df.query("Products ! = 'Pin Charger'")
# Out:
#          Countries        Products  Quantity  Revenue per product  \
# 0          Nigeria  Type A Charger     292.0                    5
# 1            Ghana  Type A Charger     974.0                    5
# 2          Nigeria  Type A Charger    2518.0                    5
# 3            Kenya  Type A Charger    1006.0                    5
# 4            Kenya  Type A Charger     367.0                    5
# ...            ...             ...       ...                  ...
# 1235         Kenya    Mini Charger    1175.0                    3
# 1236       Nigeria    Mini Charger    2954.0                    3
# 1237         Kenya    Mini Charger     552.0                    3
# 1238        Zambia    Mini Charger     293.0                    3
# 1239  South Africa    Mini Charger    1806.0                    3
#
#       Cost per product Order Date  Revenue     Cost   Profit     Month  Year
# 0                 2.00 2022-02-01   1460.0   584.00   876.00  February  2022
# ...

# %%
#Two types of products(Type A Charger and Pin Charger)
df.query("Products in ('Type A Charger', 'Pin Charger')")
# Out:
#          Countries        Products  Quantity  Revenue per product  \
# 0          Nigeria  Type A Charger     292.0                    5
# 1            Ghana  Type A Charger     974.0                    5
# 2          Nigeria  Type A Charger    2518.0                    5
# 3            Kenya  Type A Charger    1006.0                    5
# 4            Kenya  Type A Charger     367.0                    5
# ...            ...             ...       ...                  ...
# 1345        Zambia     Pin Charger     663.0                    6
# 1346  South Africa     Pin Charger    2574.0                    6
# 1347  South Africa     Pin Charger    2438.0                    6
# 1348  South Africa     Pin Charger     914.0                    6
# 1349  South Africa     Pin Charger     914.0                    6
#
#       Cost per product Order Date  Revenue     Cost   Profit      Month  Year
# 0                 2.00 2022-02-01   1460.0   584.00   876.00   February  2022
# ...

# %%
#Profit Greater than N-Value
df.query("`Profit` >= 2000")
# Out:
#          Countries        Products  Quantity  Revenue per product  \
# 1            Ghana  Type A Charger     974.0                    5
# 2          Nigeria  Type A Charger    2518.0                    5
# 3            Kenya  Type A Charger    1006.0                    5
# 5            Ghana  Type A Charger     883.0                    5
# 7            Ghana  Type A Charger     788.0                    5
# ...            ...             ...       ...                  ...
# 1345        Zambia     Pin Charger     663.0                    6
# 1346  South Africa     Pin Charger    2574.0                    6
# 1347  South Africa     Pin Charger    2438.0                    6
# 1348  South Africa     Pin Charger     914.0                    6
# 1349  South Africa     Pin Charger     914.0                    6
#
#       Cost per product Order Date  Revenue     Cost   Profit      Month  Year
# 1                 2.00 2022-02-01   4870.0  1948.00  2922.00   February  2022
# ...

# %%
#Filters between different values
df.query("`Profit` >= 2000 and `Profit` <=7000")
# Out:
#          Countries        Products  Quantity  Revenue per product  \
# 1            Ghana  Type A Charger     974.0                    5
# 3            Kenya  Type A Charger    1006.0                    5
# 5            Ghana  Type A Charger     883.0                    5
# 7            Ghana  Type A Charger     788.0                    5
# 9     South Africa  Type A Charger    1143.0                    5
# ...            ...             ...       ...                  ...
# 1337         Kenya     Pin Charger    1013.0                    6
# 1338         Ghana     Pin Charger    1575.0                    6
# 1345        Zambia     Pin Charger     663.0                    6
# 1348  South Africa     Pin Charger     914.0                    6
# 1349  South Africa     Pin Charger     914.0                    6
#
#       Cost per product Order Date  Revenue     Cost   Profit      Month  Year
# 1                 2.00 2022-02-01   4870.0  1948.00  2922.00   February  2022
# ...

# %%
#Filters between Dates
df.query("`Order Date` >= '2022-02-01' and `Order Date` <= '2022-05-31'")
# Out:
#          Countries        Products  Quantity  Revenue per product  \
# 0          Nigeria  Type A Charger     292.0                    5
# 1            Ghana  Type A Charger     974.0                    5
# 16          Zambia  Type A Charger    2296.0                    5
# 17          Zambia  Type A Charger    1030.0                    5
# 18    South Africa  Type A Charger    1514.0                    5
# ...            ...             ...       ...                  ...
# 1313  South Africa     Pin Charger     790.0                    6
# 1338         Ghana     Pin Charger    1575.0                    6
# 1339  South Africa     Pin Charger     606.0                    6
# 1343         Ghana     Pin Charger     500.0                    6
# 1344        Zambia     Pin Charger    2826.0                    6
#
#       Cost per product Order Date  Revenue     Cost   Profit     Month  Year
# 0                 2.00 2022-02-01   1460.0   584.00   876.00  February  2022
# ...

# %%
#Filters in Ember months
df[df["Month"].str.contains("ber")]
# Out:
#          Countries        Products  Quantity  Revenue per product  \
# 6           Zambia  Type A Charger     549.0                    5
# 7            Ghana  Type A Charger     788.0                    5
# 8            Ghana  Type A Charger    2472.0                    5
# 9     South Africa  Type A Charger    1143.0                    5
# 10         Nigeria  Type A Charger    1725.0                    5
# ...            ...             ...       ...                  ...
# 1345        Zambia     Pin Charger     663.0                    6
# 1346  South Africa     Pin Charger    2574.0                    6
# 1347  South Africa     Pin Charger    2438.0                    6
# 1348  South Africa     Pin Charger     914.0                    6
# 1349  South Africa     Pin Charger     914.0                    6
#
#       Cost per product Order Date  Revenue     Cost   Profit      Month  Year
# 6                 2.00 2021-09-01   2745.0  1098.00  1647.00  September  2021
# ...

# %%
#Filtering based on multiple conditions(Countries and Products)
df.query("`Countries` == 'Nigeria' and `Products` == 'Type A Charger'")
# Out:
#     Countries        Products  Quantity  Revenue per product  \
# 0     Nigeria  Type A Charger     292.0                    5
# 2     Nigeria  Type A Charger    2518.0                    5
# 10    Nigeria  Type A Charger    1725.0                    5
# 12    Nigeria  Type A Charger    2152.0                    5
# 13    Nigeria  Type A Charger    1817.0                    5
# ..        ...             ...       ...                  ...
# 834   Nigeria  Type A Charger     700.0                    5
# 835   Nigeria  Type A Charger    2222.0                    5
# 839   Nigeria  Type A Charger    1614.0                    5
# 842   Nigeria  Type A Charger    2559.0                    5
# 850   Nigeria  Type A Charger     723.0                    5
#
#      Cost per product Order Date  Revenue    Cost  Profit     Month  Year
# 0                 2.0 2022-02-01   1460.0   584.0   876.0  February  2022
# 2                 2.0 2022-06-01  12590.0  5036.0  7554.0      June  2022
# ...

# %%
#Filtering based on multiple conditions(Revenue)
df.query("`Countries` == 'Nigeria' and `Revenue` >= 2000")
# Out:
#      Countries        Products  Quantity  Revenue per product  \
# 2      Nigeria  Type A Charger    2518.0                    5
# 10     Nigeria  Type A Charger    1725.0                    5
# 12     Nigeria  Type A Charger    2152.0                    5
# 13     Nigeria  Type A Charger    1817.0                    5
# 27     Nigeria  Type A Charger    2363.0                    5
# ...        ...             ...       ...                  ...
# 1308   Nigeria     Pin Charger    1269.0                    6
# 1319   Nigeria     Pin Charger    1916.0                    6
# 1321   Nigeria     Pin Charger     384.0                    6
# 1326   Nigeria     Pin Charger    1808.0                    6
# 1331   Nigeria     Pin Charger    2632.0                    6
#
#       Cost per product Order Date  Revenue     Cost   Profit     Month  Year
# 2                 2.00 2022-06-01  12590.0  5036.00  7554.00      June  2022
# ...

# %%
#Filtering Cost, Products andd Profit
#df.query("`Products` == 'Type A Charger' and `Cost`>=1000 and `Profit` <3000")
df.query("`Products` in('Type A Charger', 'Pin Charger') and `Cost` >=1000 and `Profit` <3000")
# Out:
#          Countries        Products  Quantity  Revenue per product  \
# 1            Ghana  Type A Charger     974.0                    5
# 5            Ghana  Type A Charger     883.0                    5
# 6           Zambia  Type A Charger     549.0                    5
# 7            Ghana  Type A Charger     788.0                    5
# 11    South Africa  Type A Charger     912.0                    5
# ...            ...             ...       ...                  ...
# 1339  South Africa     Pin Charger     606.0                    6
# 1343         Ghana     Pin Charger     500.0                    6
# 1345        Zambia     Pin Charger     663.0                    6
# 1348  South Africa     Pin Charger     914.0                    6
# 1349  South Africa     Pin Charger     914.0                    6
#
#       Cost per product Order Date  Revenue     Cost   Profit      Month  Year
# 1                 2.00 2022-02-01   4870.0  1948.00  2922.00   February  2022
# ...

# %%
#Filtering profits between dates that is greater than N-Value
df.query("`Profit` >=3000 and `Order Date` >= '2022-02-01' and `Order Date` <= '2022-05-31'")
# Out:
#          Countries        Products  Quantity  Revenue per product  \
# 16          Zambia  Type A Charger    2296.0                    5
# 17          Zambia  Type A Charger    1030.0                    5
# 18    South Africa  Type A Charger    1514.0                    5
# 19    South Africa  Type A Charger    4492.5                    5
# 27         Nigeria  Type A Charger    2363.0                    5
# ...            ...             ...       ...                  ...
# 1287       Nigeria     Pin Charger    1262.0                    6
# 1309        Zambia     Pin Charger    1967.0                    6
# 1310         Ghana     Pin Charger    2628.0                    6
# 1338         Ghana     Pin Charger    1575.0                    6
# 1344        Zambia     Pin Charger    2826.0                    6
#
#       Cost per product Order Date  Revenue     Cost    Profit     Month  Year
# 16                2.00 2022-02-01  11480.0  4592.00   6888.00  February  2022
# ...

# %%
#Filtering between Ember months
#df.query("`Profit` > 3000 and `Month` in('September', 'October', 'November', 'December')")
df.query("`Profit` > 3000 and `Order Date` > '2022-08-31'")
# Out:
#          Countries        Products  Quantity  Revenue per product  \
# 8            Ghana  Type A Charger    2472.0                    5
# 9     South Africa  Type A Charger    1143.0                    5
# 13         Nigeria  Type A Charger    1817.0                    5
# 14           Kenya  Type A Charger    1513.0                    5
# 25    South Africa  Type A Charger    2905.0                    5
# ...            ...             ...       ...                  ...
# 1315  South Africa     Pin Charger    1596.0                    6
# 1318         Kenya     Pin Charger    2665.0                    6
# 1326       Nigeria     Pin Charger    1808.0                    6
# 1328  South Africa     Pin Charger     986.0                    6
# 1337         Kenya     Pin Charger    1013.0                    6
#
#       Cost per product Order Date  Revenue     Cost   Profit      Month  Year
# 8                 2.00 2022-09-01  12360.0  4944.00  7416.00  September  2022
# ...

# %%
#PIVOT TABLE - SUMMARY OF THE PRODUCTS
numeric_cols = df.select_dtypes(include=['int64', 'float64']).columns
df.pivot_table(index="Products", values=numeric_cols, aggfunc="sum")

df.pivot_table(index="Products", values=["Quantity", "Cost per product", "Revenue per product", "Revenue", "Profit", "Cost"], aggfunc="sum")
# Out:
#                       Cost  Cost per product      Profit  Quantity    Revenue  \
# Products
# Iphone Charger   440538.00            279.00   734230.00  293692.0  1174768.0
# Mini Charger     421957.50            272.50   590740.50  337566.0  1012698.0
# Pin Charger      895848.25            602.25  1058729.75  325763.0  1954578.0
# Type A Charger  1188135.00            706.00  1782202.50  594067.5  2970337.5
# Type B Charger    61679.20             37.20   246716.80  308396.0   308396.0
# Type C Charger   683386.00            413.60   869764.00  310630.0  1553150.0
#
#                 Revenue per product
# Products
# Iphone Charger                  744
# Mini Charger                    654
# Pin Charger                    1314
# Type A Charger                 1765
# Type B Charger                  186
# Type C Charger                  940

# %%
#Summary of Profits by Products
df.pivot_table(index = "Products",
               values = "Profit",
               aggfunc= "sum")
# Out:
#                     Profit
# Products
# Iphone Charger   734230.00
# Mini Charger     590740.50
# Pin Charger     1058729.75
# Type A Charger  1782202.50
# Type B Charger   246716.80
# Type C Charger   869764.00

# %%
#Summary of Profit, Revenue by Products
df.pivot_table(index = "Products",
               values = ["Profit", "Revenue"],
               aggfunc= "sum")
# Out:
#                     Profit    Revenue
# Products
# Iphone Charger   734230.00  1174768.0
# Mini Charger     590740.50  1012698.0
# Pin Charger     1058729.75  1954578.0
# Type A Charger  1782202.50  2970337.5
# Type B Charger   246716.80   308396.0
# Type C Charger   869764.00  1553150.0

# %%
#Summary of Profits by Products and Countries
df.pivot_table(index = ["Products", "Countries"],
               values = "Profit",
               aggfunc= "sum")


df.pivot_table(index = "Products",
               columns = "Countries",
               values = "Profit",
               aggfunc= "sum")
# Out:
# Countries          Ghana     Kenya    Nigeria  South Africa     Zambia
# Products
# Iphone Charger  136120.0  124720.0  174020.00      129090.0  170280.00
# Mini Charger     91451.5  108958.5  144369.75      120750.0  125210.75
# Pin Charger     172510.0  201825.0  211016.00      235417.0  237961.75
# Type A Charger  347199.0  300741.0  398823.00      362370.0  373069.50
# Type B Charger   50806.4   44897.6   50381.60       50580.0   50051.20
# Type C Charger  159017.6  171441.2  163699.20      198629.2  176976.80

# %%
#Summary of Profits, Revenue by Products and Countries
df.pivot_table(index = "Products",
               columns = "Countries",
               values = ["Profit", "Revenue"],
               aggfunc= "sum")
# Out:
#                   Profit                                               \
# Countries          Ghana     Kenya    Nigeria South Africa     Zambia
# Products
# Iphone Charger  136120.0  124720.0  174020.00     129090.0  170280.00
# Mini Charger     91451.5  108958.5  144369.75     120750.0  125210.75
# Pin Charger     172510.0  201825.0  211016.00     235417.0  237961.75
# Type A Charger  347199.0  300741.0  398823.00     362370.0  373069.50
# Type B Charger   50806.4   44897.6   50381.60      50580.0   50051.20
# Type C Charger  159017.6  171441.2  163699.20     198629.2  176976.80
#
#                  Revenue
# Countries          Ghana     Kenya   Nigeria South Africa    Zambia
# Products
# Iphone Charger  217792.0  199552.0  278432.0     206544.0  272448.0
# Mini Charger    156774.0  186786.0  247491.0     207000.0  214647.0
# Pin Charger     318480.0  372600.0  389568.0     434616.0  439314.0
# Type A Charger  578665.0  501235.0  664705.0     603950.0  621782.5
# ...

# %%
#Summary of Profits by Months and Year
df.pivot_table(index = "Month",
               columns = "Year",
               values = "Profit",
               aggfunc= "sum")
# Out:
# Year           2021       2022
# Month
# April           NaN  380024.25
# August          NaN  304065.40
# December   254405.5  454461.40
# February        NaN  249619.50
# January         NaN  323473.00
# July            NaN  337161.10
# June            NaN  468624.90
# March           NaN  253644.10
# May             NaN  242685.70
# November   307190.5  250502.70
# October    439556.2  499081.10
# September  245614.1  272274.10

# %%
#Sort Month in Descending order
dfpivot = df.pivot_table(index = "Month",
               columns = "Year",
               values = "Profit",
               aggfunc= "sum")
dfpivot.sort_values(by=['Month'], ascending = True)
# Out:
# Year           2021       2022
# Month
# April           NaN  380024.25
# August          NaN  304065.40
# December   254405.5  454461.40
# February        NaN  249619.50
# January         NaN  323473.00
# July            NaN  337161.10
# June            NaN  468624.90
# March           NaN  253644.10
# May             NaN  242685.70
# November   307190.5  250502.70
# October    439556.2  499081.10
# September  245614.1  272274.10

# %%
#Sort Month in order from January - December
dfpivot = df.pivot_table(index = "Month",
               columns = "Year",
               values = "Profit",
               aggfunc= "sum")
month_dict ={'January':1, 'February':2, 'March':3,'April':4, 'May':5, 'June':6, 'July':7, 'August':8, 'September':9, 'October':10, 'November':11, 'December':12}
dfpivot.sort_values('Month', key = lambda x : x.apply(lambda x : month_dict[x]))
# Out:
# Year           2021       2022
# Month
# January         NaN  323473.00
# February        NaN  249619.50
# March           NaN  253644.10
# April           NaN  380024.25
# May             NaN  242685.70
# June            NaN  468624.90
# July            NaN  337161.10
# August          NaN  304065.40
# September  245614.1  272274.10
# October    439556.2  499081.10
# November   307190.5  250502.70
# December   254405.5  454461.40

# %%
df.pivot_table(index = "Countries",
               columns = "Products",
               values = "Profit",
               aggfunc= "sum")
# Out:
# Products      Iphone Charger  Mini Charger  Pin Charger  Type A Charger  \
# Countries
# Ghana               136120.0      91451.50    172510.00        347199.0
# Kenya               124720.0     108958.50    201825.00        300741.0
# Nigeria             174020.0     144369.75    211016.00        398823.0
# South Africa        129090.0     120750.00    235417.00        362370.0
# Zambia              170280.0     125210.75    237961.75        373069.5
#
# Products      Type B Charger  Type C Charger
# Countries
# Ghana                50806.4        159017.6
# Kenya                44897.6        171441.2
# Nigeria              50381.6        163699.2
# South Africa         50580.0        198629.2
# Zambia               50051.2        176976.8

# %%
# Summary of number of products sold
df.pivot_table(index = "Countries",
               columns = "Products",
               values = "Profit",
               aggfunc= "count")
# Out:
# Products      Iphone Charger  Mini Charger  Pin Charger  Type A Charger  \
# Countries
# Ghana                     36            40           44              72
# Kenya                     40            44           44              70
# Nigeria                   40            44           40              72
# South Africa              34            46           47              70
# Zambia                    36            44           44              69
#
# Products      Type B Charger  Type C Charger
# Countries
# Ghana                     40              40
# Kenya                     36              36
# Nigeria                   36              36
# South Africa              34              40
# Zambia                    40              36

# %%
#Column Chart of Profit by Products without Labelling
barchart = df.pivot_table(index = "Products",
                         values = "Profit",
                         aggfunc = "sum")
barchart.plot(kind = "bar")
# Out:
# <Axes: xlabel='Products'>

# %%
#Column Chart of Profit by Products with Labelling
from matplotlib import pyplot as plt
columnchart = df.pivot_table(index = "Products",
                         values = "Profit",
                         aggfunc = "sum")
columnchart.plot(kind = "bar")
plt.title("Profit by Products")
plt.xlabel("Profit")
plt.ylabel("Products")
# Out:
# Text(0, 0.5, 'Products')

# %%
#Bar Chart of Profit by Products with Labelling
from matplotlib import pyplot as plt
barchart = df.pivot_table(index = "Products",
                         values = "Profit",
                         aggfunc = "sum")
barchart.plot(kind = "barh")
plt.title("Profit by Products")
plt.xlabel("Profit")
plt.ylabel("Products")
# Out:
# Text(0, 0.5, 'Products')

# %%
#Pie Chart of Revenue by Countries with Labelling
from matplotlib import pyplot as plt
piechart = df.pivot_table(index = "Countries",
                         values = "Revenue",
                         aggfunc = "sum")
piechart.plot(kind = "pie", y = 'Revenue', autopct = '%1.1f%%')
plt.title("Revenue by Countries")
# Out:
# Text(0.5, 1.0, 'Revenue by Countries')

# %%
#Sorted Column Chart
from matplotlib import pyplot as plt
dfpivot = df.pivot_table(index = "Month",
                         values = "Profit",
                         aggfunc = "sum")
month_dict ={'January':1, 'February':2, 'March':3,'April':4, 'May':5, 'June':6, 'July':7, 'August':8, 'September':9, 'October':10, 'November':11, 'December':12}
dftable = dfpivot.sort_values('Month', key = lambda x : x.apply(lambda x : month_dict[x]))
dftable.plot(kind = "bar")

plt.title("Profit by Month")
plt.xlabel("Profit")
plt.ylabel("Month")
# Out:
# Text(0, 0.5, 'Month')

# %%
#Line Chart
from matplotlib import pyplot as plt
dfpivot = df.pivot_table(index = "Month",
                         values = "Profit",
                         aggfunc = "sum")
month_dict ={'January':1, 'February':2, 'March':3,'April':4, 'May':5, 'June':6, 'July':7, 'August':8, 'September':9, 'October':10, 'November':11, 'December':12}
dftable = dfpivot.sort_values('Month', key = lambda x : x.apply(lambda x : month_dict[x]))
dftable.plot(kind = "line")

plt.title("Profit by Month")
plt.xlabel("Profit")
plt.ylabel("Month")
# Out:
# Text(0, 0.5, 'Month')

# %%
#Area Chart
from matplotlib import pyplot as plt
dfpivot = df.pivot_table(index = "Month",
                         values = "Profit",
                         aggfunc = "sum")
month_dict ={'January':1, 'February':2, 'March':3,'April':4, 'May':5, 'June':6, 'July':7, 'August':8, 'September':9, 'October':10, 'November':11, 'December':12}
dftable = dfpivot.sort_values('Month', key = lambda x : x.apply(lambda x : month_dict[x]))
dftable.plot.area()

plt.title("Profit by Month")
plt.xlabel("Profit")
plt.ylabel("Month")
# Out:
# Text(0, 0.5, 'Month')

# %%
df.to_excel('Saved Practice Data.xlsx')
